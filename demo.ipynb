# %%
import os
import pandas as pd
import sqlite3

from sqlite3 import Error

# %% [markdown]
# #### Get current working directory

# %%
cwd = os.getcwd()

cwd
# Out:
# 'C:\\Users\\randy\\Desktop\\Personal\\github\\demo_sql'

# %% [markdown]
# #### Connect to database

# %%
def create_connection(db_file):
    
    conn = None
    
    try:
        print(sqlite3.version)
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)
    
    return conn

# %%
conn = create_connection(
    os.path.join(
        cwd,
        'pythonsqlite.db'
    )
)
# Out:
# 2.6.0

# %%
conn

# %% [markdown]
# #### Drop tables if exist from past runs

# %%
c = conn.cursor()

for table in ['deposit_marketing', 'month_mapper']:
    c.execute('DROP TABLE IF EXISTS {}'.format(table))
    
c.close()

# %% [markdown]
# #### Read local csv into pandas

# %%
df = pd.read_csv(
    os.path.join(
        'file://',
        cwd,
        'bank.csv'
    ),
    sep=','
)

# %% [markdown]
# #### Analyse schema

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %% [markdown]
# #### Create table for pandas df

# %%
columns = []

for col, data_type in df.dtypes.to_dict().items():
    
    col = 'defaulted' if col == 'default' else col
    
    columns.append(
        '{} {}'.format(col, 'integer' if data_type == 'int64' else 'text')
    )

create_tbl_stmt = '{} ({});'.format(
        'CREATE TABLE IF NOT EXISTS deposit_marketing',
        ', '.join(columns)
)

create_tbl_stmt
# Out:
# 'CREATE TABLE IF NOT EXISTS deposit_marketing (age integer, job text, marital text, education text, defaulted text, balance integer, housing text, loan text, contact text, day integer, month text, duration integer, campaign integer, pdays integer, previous integer, poutcome text, deposit text);'

# %%
def create_table(conn, create_tbl_stmt):
    
    try:
        c = conn.cursor()
        c.execute(create_tbl_stmt)
        c.close()
        
    except Error as e:
        print(e)

# %%
create_table(conn, create_tbl_stmt)

# %% [markdown]
# #### Check created table

# %%
def query_table(conn, query_tbl_stmt):
    
    result = []
    
    try:
        c = conn.cursor()
        c.execute(query_tbl_stmt)
        
        result = pd.DataFrame(
            data=[_ for _ in c],
            columns=[_[0] for _ in c.description]
        )
        
        c.close()
    
    except Error as e:
        print(e)
        
    return result

# %%
query_table(conn, 'select * from sqlite_master')
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table  deposit_marketing  deposit_marketing         2
#
#                                                  sql
# 0  CREATE TABLE deposit_marketing (age integer, j...

# %%
query_table(conn, 'select * from deposit_marketing limit 5')
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, defaulted, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, deposit]
# Index: []

# %% [markdown]
# #### Insert records

# %%
records = df.to_records(index=False).tolist()

c = conn.cursor()
c.executemany(
    'INSERT INTO deposit_marketing VALUES ({})'.format(','.join(['?' for _ in range(0, len(df.columns))])),
    records
)
c.close()
conn.commit()

# %% [markdown]
# #### Query inserted records

# %%
query_table(conn, 'select * from deposit_marketing limit 5')
# Out:
#    age         job  marital  education defaulted  balance housing loan  \
# 0   59      admin.  married  secondary        no     2343     yes   no
# 1   56      admin.  married  secondary        no       45      no   no
# 2   41  technician  married  secondary        no     1270     yes   no
# 3   55    services  married  secondary        no     2476     yes   no
# 4   54      admin.  married   tertiary        no      184      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may      1042         1     -1         0  unknown     yes
# 1  unknown    5   may      1467         1     -1         0  unknown     yes
# 2  unknown    5   may      1389         1     -1         0  unknown     yes
# 3  unknown    5   may       579         1     -1         0  unknown     yes
# 4  unknown    5   may       673         2     -1         0  unknown     yes

# %% [markdown]
# #### Distinct value in poutcome

# %%
query_table(conn, 'select distinct poutcome from deposit_marketing')
# Out:
#   poutcome
# 0  unknown
# 1    other
# 2  failure
# 3  success

# %% [markdown]
# #### Standardising value of poutcome

# %%
c = conn.cursor()
c.execute(
    '''
        update deposit_marketing
        set
            poutcome == 'unknown'
        where
            poutcome == 'other'
    '''
)
c.close()
conn.commit()

# %%
query_table(conn, 'select distinct poutcome from deposit_marketing')
# Out:
#   poutcome
# 0  unknown
# 1  failure
# 2  success

# %% [markdown]
# #### Balances summary by education and marital

# %%
query_table(
    conn,
    '''
    select
        education,
        marital,
        count(*) as tot_population,
        sum(balance) as tot_balances,
        avg(balance) as avg_balances,
        min(balance) as min_balances,
        max(balance) as max_balances
    from deposit_marketing
    group by
        education,
        marital
    order by education asc, marital desc
    '''
)
# Out:
#     education   marital  tot_population  tot_balances  avg_balances  \
# 0     primary    single             197        271800   1379.695431
# 1     primary   married            1099       1723931   1568.636033
# 2     primary  divorced             204        288816   1415.764706
# 3   secondary    single            1704       1942320   1139.859155
# 4   secondary   married            3120       4500996   1442.626923
# 5   secondary  divorced             652        656210   1006.457055
# 6    tertiary    single            1460       2637784   1806.701370
# 7    tertiary   married            1843       3433041   1862.746066
# 8    tertiary  divorced             386        738586   1913.435233
# 9     unknown    single             157        274720   1749.808917
# 10    unknown   married             289        503172   1741.079585
# 11    unknown  divorced              51         90171   1768.058824
#
#     min_balances  max_balances
# 0           -887         26965
# 1          -1489         66653
# 2           -779         37127
# 3          -1139         56831
# 4          -1965         81204
# 5           -934         12039
# 6           -880         36252
# 7          -6847         51439
# 8          -2282         52587
# 9           -461         45248
# 10         -1137         23592
# 11          -701          9224

# %% [markdown]
# #### Top 3 balance by marital

# %%
query_table(
    conn,
    '''
    select * from (
        select
            marital,
            job,
            age,
            balance,
            dense_rank() over(
                partition by marital
                order by balance desc
            ) as r1
        from deposit_marketing
    )
    where r1 < 4
    order by marital desc
    '''
)
# Out:
#      marital            job  age  balance  r1
# 0     single         admin.   43    56831   1
# 1     single     technician   39    45248   2
# 2     single     management   29    36252   3
# 3    married        retired   84    81204   1
# 4    married        retired   84    81204   1
# 5    married    blue-collar   52    66653   2
# 6    married   entrepreneur   56    51439   3
# 7   divorced  self-employed   61    52587   1
# 8   divorced  self-employed   61    52587   1
# 9   divorced        retired   75    37127   2
# 10  divorced        retired   74    29080   3

# %% [markdown]
# #### Create another table

# %%
create_table(
    conn,
    '''
    CREATE TABLE IF NOT EXISTS month_mapper (
        month text primary key,
        month_num integer
    )
    '''
)

# %%
query_table(conn, 'select * from sqlite_master')
# Out:
#     type                             name           tbl_name  rootpage  \
# 0  table                deposit_marketing  deposit_marketing         2
# 1  table                     month_mapper       month_mapper         7
# 2  index  sqlite_autoindex_month_mapper_1       month_mapper         8
#
#                                                  sql
# 0  CREATE TABLE deposit_marketing (age integer, j...
# 1  CREATE TABLE month_mapper (\n        month tex...
# 2                                               None

# %%
records = [
    ('jan', 1),
    ('feb', 2),
    ('mar', 3),
    ('apr', 4),
    ('may', 5),
    ('jun', 6),
    ('jul', 7),
    ('aug', 8),
    ('sep', 9),
    ('oct', 10),
    ('nov', 11),
    ('dec', 12)
]

c = conn.cursor()
c.executemany(
    'INSERT INTO month_mapper VALUES (?,?)',
    records
)
c.close()
conn.commit()

# %%
query_table(conn, 'select * from month_mapper')
# Out:
#    month  month_num
# 0    jan          1
# 1    feb          2
# 2    mar          3
# 3    apr          4
# 4    may          5
# 5    jun          6
# 6    jul          7
# 7    aug          8
# 8    sep          9
# 9    oct         10
# 10   nov         11
# 11   dec         12

# %% [markdown]
# #### Join dataframes

# %%
query_table(
    conn,
    '''
    select
        dm.*,
        mm.*
    from deposit_marketing dm
    inner join month_mapper mm
    on
        dm.month = mm.month
    limit 5
    '''
)
# Out:
#    age         job  marital  education defaulted  balance housing loan  \
# 0   59      admin.  married  secondary        no     2343     yes   no
# 1   56      admin.  married  secondary        no       45      no   no
# 2   41  technician  married  secondary        no     1270     yes   no
# 3   55    services  married  secondary        no     2476     yes   no
# 4   54      admin.  married   tertiary        no      184      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit  \
# 0  unknown    5   may      1042         1     -1         0  unknown     yes
# 1  unknown    5   may      1467         1     -1         0  unknown     yes
# 2  unknown    5   may      1389         1     -1         0  unknown     yes
# 3  unknown    5   may       579         1     -1         0  unknown     yes
# 4  unknown    5   may       673         2     -1         0  unknown     yes
#
#   month  month_num
# 0   may          5
# 1   may          5
# 2   may          5
# 3   may          5
# 4   may          5

# %% [markdown]
# #### Close connection

# %%
conn.close()
